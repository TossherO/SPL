# %%
import pickle

# %%
import hdbscan
import numpy as np

# %%
data = np.random.rand(100, 3)
hdbscan_clusterer = hdbscan.HDBSCAN(min_cluster_size=5, min_samples=1)
labels = hdbscan_clusterer.fit_predict(data)
# Out:
# /home/helloalone/miniconda3/envs/python310/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/helloalone/miniconda3/envs/python310/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
labels
# Out:
# array([-1,  4,  7,  2,  4,  2, -1,  5, -1,  2,  7,  5,  0,  8,  8,  8,  5,
#         3,  7,  7, -1,  1, -1,  6,  7, -1,  8,  3, -1,  1,  8,  5,  7,  6,
#         2, -1,  4, -1,  8,  3,  3,  0,  2,  0,  8,  6,  2,  6,  6, -1,  2,
#         1,  0,  0, -1,  3, -1,  4,  3, -1,  1, -1,  1,  8,  6,  0,  5, -1,
#         3,  4,  3,  8,  6,  8,  6,  7,  3,  2,  3, -1,  8,  3,  3,  8,  5,
#        -1, -1, -1,  3,  3,  6,  5,  4,  6, -1,  4,  2,  7,  8,  3])

# %%
info_path = '../data/nuscenes/nuscenes_data_info.pkl'
with open(info_path, 'rb') as f:
    data_info = pickle.load(f)

# %%
len(data_info)
# Out:
# 5

# %%
len(data_info[0]['samples'])
# Out:
# 40

# %%
data_info[0]['samples'][0].keys()
# Out:
# dict_keys(['timestamp', 'lidar_path', 'lidar2ego', 'ego2global', 'cams', 'lidar_sweep', 'labels'])

# %%
data_info[1]['samples'][10]['lidar_sweep']
# Out:
# [{'timestamp': 1531883723.998191,
#   'lidar_path': './data/nuscenes/sweeps/LIDAR_TOP/n015-2018-07-18-11-07-57+0800__LIDAR_TOP__1531883723998191.pcd.bin',
#   'ego2global': array([[-7.66304314e-01,  6.42346998e-01,  1.29626993e-02,
#            3.76807446e+02],
#          [-6.42474485e-01, -7.66079784e-01, -1.86628176e-02,
#            1.09884002e+03],
#          [-2.05754294e-03, -2.26296012e-02,  9.99741800e-01,
#            0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#            1.00000000e+00]])},
#  {'timestamp': 1531883724.047946,
#   'lidar_path': './data/nuscenes/sweeps/LIDAR_TOP/n015-2018-07-18-11-07-57+0800__LIDAR_TOP__1531883724047946.pcd.bin',
#   'ego2global': array([[-7.53811724e-01,  6.56949921e-01,  1.35899315e-02,
#            3.76666614e+02],
#          [-6.57088277e-01, -7.53594550e-01, -1.81728074e-02,
#            1.09871964e+03],
#          [-1.69732608e-03, -2.26286599e-02,  9.99742498e-01,
#            0.00000000e+00],
# ...

# %%
for i in range(0, 50, 10):
    print(i)
# Out:
# 0
# 10
# 20
# 30
# 40
